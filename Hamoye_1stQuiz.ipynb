# %% [markdown]
# # Hamoye_Quiz_1!#

# %%
import numpy as np
#np.random.bit_generator # == np.random.BitGenerator

# %%
np.version.version
# Out:
# '1.22.1'

# %%
import pandas as pd

# %%
url = "~/Desktop/cplus/FoodBalanceSheets_E_Africa_NOFLAG.csv" 
# I downloaded the file to the path above on an Ubuntu Linux device

# %%
df = pd.read_csv(url, encoding="latin-1")

# %%
df.describe() 
# mean and standard deviation was 135.235966 and 1603.403984 respectively for year 2015 from the table below
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
(df.groupby('Item').sum()) 
# total sum of Animal Fat Produced in 2014 and 2017 is 209460.54 269617.53 respectively from the table below
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
(df.groupby('Element').sum()) 
# year 2017 had the highest sum of Import Quality at 294559.09 from the table below
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
(df[['Y2016']].isnull().sum()) 
# total number of missing data in 2016 is 1535
# Out:
# Y2016    1535
# dtype: int64

# %%
((df[['Y2016']].isnull().sum())/(df[['Y2016']].notnull().sum())*(100)) 
# percentage of missing data in 2016 is 2.58
# Out:
# Y2016    2.583827
# dtype: float64

# %%
(df.corr()) 
#from the table shown below year 2014 had the highest correlation with column Element Code at 0.024457 among the year columns
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
(df.groupby('Element').sum()) 
# from the table below the year with the highest Import quantity is 2017 at 294559.09
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
(df.groupby('Element').sum()) 
# from the table below the total number of the sum of production for 2014 was 1931287.75
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
(df.groupby('Element').sum()) 
# from the table below the element with the highest sum in 2018 was Domestic supply quantity at 2161192.10
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
(df.groupby('Element').sum())
# from the table below the element with the 3rd lowest sum sum in 2018 was Protein supply quantity (g/capita/day) at 11833.56
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
(df.groupby('Area Code').count()) 
# table below shows that Area code 4{Algeria} has 1313 consecutive row entries
# Out:
#            Area  Item Code  Item  Element Code  Element  Unit  Y2014  Y2015  \
# Area Code
# 4          1313       1313  1313          1313     1313  1313   1261   1268
# 7          1424       1424  1424          1424     1424  1424   1378   1378
# 20         1378       1378  1378          1378     1378  1378   1361   1369
# 32         1460       1460  1460          1460     1460  1460   1450   1443
# 35         1260       1260  1260          1260     1260  1260   1231   1229
# 37         1344       1344  1344          1344     1344  1344   1300   1296
# 39         1343       1343  1343          1343     1343  1343   1284   1303
# 45           45         45    45            45       45    45     45     45
# 46         1413       1413  1413          1413     1413  1413   1382   1377
# 53         1285       1285  1285          1285     1285  1285   1250   1260
# 59         1488       1488  1488          1488     1488  1488   1461   1473
# ...

# %%
(df.loc[:1313, :].groupby('Element').sum()) 
# table below shows that total Import Quantity in Algeria in Y2018 is 36238.29
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                      464     311204        614916
# Export Quantity                               392     264011        579278
# Fat supply quantity (g/capita/day)            432     291489         73872
# Feed                                           88      58967        121462
# Food                                          420     282744        539910
# Food supply (kcal/capita/day)                 432     291489         71712
# Food supply quantity (kg/capita/yr)           420     282744         67725
# Import Quantity                               448     301030        628432
# Losses                                        208     139857        266396
# Other uses (non-food)                         148     101269        190698
# Processing                                    140      93537        179585
# ...

# %%
(len(pd.unique(df['Area Code']))) 
# length of Unique Entries based on Area code (which reflects countries) is 49 as shown below
# Out:
# 49
